# %% [markdown]
# <a href="https://colab.research.google.com/github/MarieGuertin/CapstoneGroup4/blob/main/tas/ckpt_to_h5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Setup**

# %%
# Timers and Such
# !git clone https://github.com/speechbrain/speechbrain.git
# Out:
# Cloning into 'speechbrain'...
# remote: Enumerating objects: 47483, done.
# remote: Counting objects: 100% (6513/6513), done.
# remote: Compressing objects: 100% (1041/1041), done.
# remote: Total 47483 (delta 5622), reused 6095 (delta 5405), pack-reused 40970
# Receiving objects: 100% (47483/47483), 60.04 MiB | 13.77 MiB/s, done.
# Resolving deltas: 100% (30712/30712), done.

# %%
# Capstone
# !git clone https://github.com/MarieGuertin/CapstoneGroup4.git
# Out:
# Cloning into 'CapstoneGroup4'...
# remote: Enumerating objects: 4059, done.
# remote: Counting objects: 100% (4059/4059), done.
# remote: Compressing objects: 100% (1865/1865), done.
# remote: Total 4059 (delta 2184), reused 3811 (delta 1969), pack-reused 0
# Receiving objects: 100% (4059/4059), 76.68 MiB | 13.72 MiB/s, done.
# Resolving deltas: 100% (2184/2184), done.
# Checking out files: 100% (3433/3433), done.

# %%
# !pip install speechbrain
# Out:
# ...
#      |████████████████████████████████| 408 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 40.6 MB/s
# ...
#      |████████████████████████████████| 67 kB 3.8 MB/s
# ...
#      |████████████████████████████████| 109 kB 53.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 49.9 MB/s
# ...
#      |████████████████████████████████| 546 kB 60.8 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# %cd speechbrain
# !pip install -r requirements.txt
# !pip install --editable .
# Out:
# /content/speechbrain
# Ignoring SoundFile: markers 'sys_platform == "win32"' don't match your environment
# ...
#      |████████████████████████████████| 97 kB 2.8 MB/s
# ...
#      |████████████████████████████████| 69 kB 5.6 MB/s
# ...
#      |████████████████████████████████| 51 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 246 kB 46.0 MB/s
# ...
#      |████████████████████████████████| 58 kB 3.8 MB/s
# ...
#      |████████████████████████████████| 195 kB 47.2 MB/s
# ...
#      |████████████████████████████████| 843 kB 33.3 MB/s
# ...
#      |████████████████████████████████| 59 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 8.7 MB 34.5 MB/s
# ...
#      |████████████████████████████████| 98 kB 6.3 MB/s
# ...
#      |████████████████████████████████| 461 kB 61.5 MB/s
# ...
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Attempting uninstall: entrypoints
#     Found existing installation: entrypoints 0.4
# ...

# %% [markdown]
# ##**Convert Tokenizer Model to .h5**

# %%
from speechbrain.pretrained import EndToEndSLU
slu = EndToEndSLU.from_hparams("speechbrain/slu-timers-and-such-direct-librispeech-asr")
# Out:
# Downloading:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/37.2M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/238k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.49k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.41k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/480M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/212M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/253k [00:00<?, ?B/s]

# %%
# !wget https://huggingface.co/speechbrain/slu-timers-and-such-direct-librispeech-asr/resolve/main/tokenizer.ckpt
# !wget https://huggingface.co/speechbrain/slu-timers-and-such-direct-librispeech-asr/resolve/main/model.ckpt
# Out:
# --2022-02-28 21:52:04--  https://huggingface.co/speechbrain/slu-timers-and-such-direct-librispeech-asr/resolve/main/tokenizer.ckpt
# Resolving huggingface.co (huggingface.co)... 54.205.126.93, 34.204.221.201, 34.224.55.150, ...
# Connecting to huggingface.co (huggingface.co)|54.205.126.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 238213 (233K) [application/octet-stream]
# Saving to: ‘tokenizer.ckpt’
#
# tokenizer.ckpt      100%[===================>] 232.63K   430KB/s    in 0.5s
#
# 2022-02-28 21:52:05 (430 KB/s) - ‘tokenizer.ckpt’ saved [238213/238213]
#
# --2022-02-28 21:52:06--  https://huggingface.co/speechbrain/slu-timers-and-such-direct-librispeech-asr/resolve/main/model.ckpt
# Resolving huggingface.co (huggingface.co)... 54.205.126.93, 34.204.221.201, 34.224.55.150, ...
# Connecting to huggingface.co (huggingface.co)|54.205.126.93|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
from tensorflow.python.tools.inspect_checkpoint import print_tensors_in_checkpoint_file
print_tensors_in_checkpoint_file(file_name='model.ckpt', tensor_name='', all_tensors=False)
# Out:
# Unable to open table file model.ckpt: DATA_LOSS: not an sstable (bad magic number): perhaps your file is in a different file format and you need to use a different restore operator?
