# %% [markdown]
# <a href="https://colab.research.google.com/github/MarieGuertin/CapstoneGroup4/blob/main/tas/run_the_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Setup**

# %%
# Timers and Such
# !git clone https://github.com/speechbrain/speechbrain.git
# Out:
# Cloning into 'speechbrain'...
# remote: Enumerating objects: 47483, done.
# remote: Counting objects: 100% (6513/6513), done.
# remote: Compressing objects: 100% (1041/1041), done.
# remote: Total 47483 (delta 5622), reused 6095 (delta 5405), pack-reused 40970
# Receiving objects: 100% (47483/47483), 60.04 MiB | 17.05 MiB/s, done.
# Resolving deltas: 100% (30712/30712), done.
# Cloning into 'CapstoneGroup4'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# Capstone
# !git clone https://github.com/MarieGuertin/CapstoneGroup4.git
# Out:
# Cloning into 'CapstoneGroup4'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !pip install speechbrain
# Out:
# ...
#      |████████████████████████████████| 408 kB 8.8 MB/s
# ...
#      |████████████████████████████████| 67 kB 7.1 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 62.2 MB/s
# ...
#      |████████████████████████████████| 109 kB 64.4 MB/s
# ...
#      |████████████████████████████████| 596 kB 57.2 MB/s
# ...
#      |████████████████████████████████| 546 kB 55.0 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# %cd speechbrain
# !pip install -r requirements.txt
# !pip install --editable .
# Out:
# /content/speechbrain
# Ignoring SoundFile: markers 'sys_platform == "win32"' don't match your environment
# ...
#      |████████████████████████████████| 97 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 69 kB 8.6 MB/s
# ...
#      |████████████████████████████████| 51 kB 8.0 MB/s
# ...
#      |████████████████████████████████| 246 kB 69.1 MB/s
# ...
#      |████████████████████████████████| 58 kB 8.7 MB/s
# ...
#      |████████████████████████████████| 195 kB 70.9 MB/s
# ...
#      |████████████████████████████████| 843 kB 56.0 MB/s
# ...
#      |████████████████████████████████| 59 kB 6.0 MB/s
# ...
#      |████████████████████████████████| 8.7 MB 51.9 MB/s
# ...
#      |████████████████████████████████| 98 kB 9.2 MB/s
# ...
#      |████████████████████████████████| 461 kB 12.3 MB/s
# ...
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Attempting uninstall: entrypoints
#     Found existing installation: entrypoints 0.4
# ...

# %% [markdown]
# ##**SLU Timers and Such**

# %% [markdown]
# ###Download pretrained model with direct approach

# %%
from speechbrain.pretrained import EndToEndSLU
slu = EndToEndSLU.from_hparams("speechbrain/slu-timers-and-such-direct-librispeech-asr",run_opts={"device":"cuda"})
# Out:
# Downloading:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/37.2M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/238k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.49k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.41k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/480M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/212M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/253k [00:00<?, ?B/s]

# %% [markdown]
# ###**Inference**

# %%
slu.decode_file("speechbrain/slu-timers-and-such-direct-librispeech-asr/math.wav")
# Out:
# decoupled		LM	    prepare.py	       README.md
# direct			math.wav    pretrained_models  Tokenizer
# extra_requirements.txt	multistage  __pycache__

# %% [markdown]
# ### **Training the model**

# %% [markdown]
# ##### Info
# - recipes/timers-and-such/direct/hparams/train.yaml file has all the parameters to tweek:
# (important ones: beam_searcher/ batch_size/ lr/ number_of_epochs)
# - Zip file of the timers and such dataset: https://zenodo.org/record/4623772/files/timers-and-such-v1.0.zip?download=1

# %%
# %cd  '/speechbrain/recipes/timers-and-such/direct'
# !python train.py hparams/train.yaml --data_folder='/localscratch/timers-and-such/' --number_of_epochs=2 --train_splits=["train-real", "train-synth"]
# Out:
# /content/drive/MyDrive/git/speechbrain/recipes/timers-and-such/direct
# /localscratch/timers-and-such/rirs_noises.zip exists. Skipping download
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: results/train-real-and-synth/1986
# ...
# timers-and-such-v1.0.zip?download=1:  18% 2.34G/13.1G [03:18<15:17, 11.8MB/s]
# speechbrain.core - Exception:
# Traceback (most recent call last):
#   File "train.py", line 328, in <module>
#     "skip_prep": hparams["skip_prep"],
#   File "/usr/local/lib/python3.7/dist-packages/speechbrain/utils/distributed.py", line 61, in run_on_main
#     func(*args, **kwargs)
#   File "/content/drive/MyDrive/git/speechbrain/recipes/timers-and-such/direct/prepare.py", line 56, in prepare_TAS
#     download_file(url, zip_location, unpack=True)
#   File "/usr/local/lib/python3.7/dist-packages/speechbrain/utils/data_utils.py", line 302, in download_file
#     source, filename=dest, reporthook=t.update_to
# ...
